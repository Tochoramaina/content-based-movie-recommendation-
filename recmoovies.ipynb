# %%
# importing prerequisite libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from collections import Counter

# %% [markdown]
# we will  upload our dataset from a local directory.

# %% [markdown]
# This dataset can also be downloaded from www.kaggle/datasets.com

# %%
# uploading our dataset
df = pd.read_csv(r'../tochora/puoy/tmdb_5000_movies.csv')
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# shape of the dataset
df.shape
# Out:
# (4803, 20)

# %% [markdown]
# this dataset has 4803 rows  and 20 columns

# %%
# credit dataset
df2 = pd.read_csv(r'../tochora/puoy/tmdb_5000_credits.csv')
df2.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %% [markdown]
# we will concat the two datasets into one full dataset

# %%
df = pd.merge(df, df2, on='title')
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# shape of our full dataset
df.shape
# Out:
# (4809, 23)

# %% [markdown]
# our dataset has 4809 rows and 23 columns

# %%
# checing entries in genres column
df['genres'].loc[0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %% [markdown]
# genres has entries made up of dictionaries composed of keys and values. we will remove keys and remain with values which are vital in our analysis

# %%
# evaluating texts before we cleanse them
from ast import literal_eval
literal_eval('{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name":"Science Fiction"}')
# Out:
# ({'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'})

# %% [markdown]
# below is a function that will remove keys that is 'id' and 'name' and leave us with values like action, adventure, fantasy and science fiction

# %%
# a function to cleanse our data
def convert(obj):
    L = []
    for i in literal_eval(obj):
        L.append(i['name'])
    return L

# %%
#applying our function to genre column
df['genres'] = df['genres'].apply(convert)

# %%
# applying the same fuction to these columns since they have enties that have the same problem
df['production_companies'] = df['production_companies'].apply(convert)
df['spoken_languages'] = df['spoken_languages'].apply(convert)
df['keywords'] = df['keywords'].apply(convert)
df['cast'] = df['cast'].apply(convert)
df['crew'] = df['crew'].apply(convert)

# %% [markdown]
# checking entries in production countries column

# %%
df['production_countries'].iloc[0]
# Out:
# '[{"iso_3166_1": "US", "name": "United States of America"}, {"iso_3166_1": "GB", "name": "United Kingdom"}]'

# %%
#evaluating entries in production countries
literal_eval('[{"iso_3166_1": "US", "name": "United States of America"}, {"iso_3166_1": "GB", "name": "United Kingdom"}]')
# Out:
# [{'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'}]

# %%
#a function to remove unnecessary entries in production countries
def convert2(obj):
    corpus = []
    for i in literal_eval(obj):
        corpus.append(i['name'])
    return corpus

# %%
# applying our function
df['production_countries'] = df['production_countries'].apply(convert2)

# %%
# display of our dataset after applying those changes
df.head().T
# Out:
#                                                                       0  \
# budget                                                        237000000
# genres                    [Action, Adventure, Fantasy, Science Fiction]
# homepage                                    http://www.avatarmovie.com/
# id                                                                19995
# keywords              [culture clash, future, space war, space colon...
# original_language                                                    en
# original_title                                                   Avatar
# overview              In the 22nd century, a paraplegic Marine is di...
# popularity                                                   150.437577
# production_companies  [Ingenious Film Partners, Twentieth Century Fo...
# production_countries         [United States of America, United Kingdom]
# release_date                                                 2009-12-10
# ...

# %% [markdown]
# Data visualisation

# %%
genres_list = []
for i in df['genres']:
    genres_list.extend(i)
fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(14, 7))
df_plot = pd.DataFrame(Counter(genres_list).most_common(5), columns=['genre', 'total'])
ax = sns.barplot(data=df_plot, x='genre', y='total', ax=axes[0])
ax.set_title('Top 5 Genres in Movies', fontsize=18, weight=600, color='#333d29')
sns.despine()
df_plot_full = pd.DataFrame([Counter(genres_list)]).transpose().sort_values(by=0, ascending=False)
df_plot.loc[len(df_plot)] = {"genre": "Others", "total": df_plot_full[4:].sum()[0]}
plt.title('Percentage Ratio of Movie Genres', fontsize=18, weight=600)
wedges, texts, autotext = axes[1].pie(df_plot['total'], labels = df_plot['genre'], autopct= "%.2f%%", explode= [0, 0, 0, 0,0, 0.1])

# %% [markdown]
# Drama has the largest bar, follwed by commedy while Romance has the lowest bar.

# %% [markdown]
# Drama movies/shows were the most watched by 17.59&, followed by commedy at 13.18%, thriller at 9.75% while Romance with 6.85% was the least watched.Drama shows/movies are highly preferred making production companies to release more of them.

# %% [markdown]
# NB: Others are not included in our analysis since it is not specified.

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
plt.figure(figsize=(12, 6))
sns.displot(x=df['release_date'], kind='hist', kde=True, color='#f0d8b6', aspect=3, line_kws = {"color": "blue"}, facecolor='#b0d5ce')
plt.title("Distribution of total released movies")
# Out:
# Text(0.5, 1.0, 'Distribution of total released movies')

# %% [markdown]
# from the figure during 1940s bars are low but are gradually rising with the  peak between 2000 and 2020.This shows that from 1940s movies/shows released were few but there was a gradual increase in their prooduction which peaked around 2000 to 2020.

# %% [markdown]
# From 2000 to 2020 there was in increase in released movies or shows maybe because of pc revolution, internet revolution and also increased use of smartphones, stream apps which enabled people to watch them online

# %% [markdown]
# Looking at the trend, 2020 had the lowest bar indicating that covid-19 had an adverse effects on the number of movies that were supposed to be released

# %%
sns.relplot(x=df['vote_average'], y =df['popularity'], size=df['vote_count'], sizes=(20, 200), aspect=2)
plt.title("Relationship between Popularity and Ratings")
# Out:
# Text(0.5, 1.0, 'Relationship between Popularity and Ratings')

# %% [markdown]
# Movies that either got rating 0 or 10 are basically caused by small number of voter. As the vote count increase, the rating is most likely around 5 to 8.5
# It's clear that popular movies will get more vote count as shown from above plot

# %% [markdown]
# Correlation

# %% [markdown]
# correlation refers to linear relationship between two variables where one variable might be directly on indirectly related to one another at either equal or uneaqual proportion. Correlation can either be negative or positive correlated depending on the sighn of the index. Negative sign = negative correlation and positive sighn = positive correlation.

# %% [markdown]
# correlation index of 0 to 0.25 is considered weak correlation, 2.5 to 7.5 is considered fairly correlated while 7.5 to 1 shows that the values are highly
# correlated

# %%
plt.figure(figsize=(12, 9))
plt.title("Correlation of features in our data")
sns.heatmap(df.corr(), annot=True, cmap='plasma')
plt.show()

# %% [markdown]
# Vote_count has 78% in relation to revenue showing that there is a higher correlation between vote count and revenue.This means that when vote count increase, revenue increaseby 78%

# %% [markdown]
# revenue is 73% linearly corrrelated to budget showing there is high colleration between budget and revenue thus increase in budget leads to increasein revenue by 73% .Budget and vote average has low correlation of 0.093% meaning that budget has noeffect on vote average

# %%
# converting the datatype of overview to string
df['overview'] = df['overview'].astype(str)

# %% [markdown]
# WordCloud

# %% [markdown]
# This is an image made up of words where the size and frequency of a word depicts its importance in a particular subject.We are going to identify most vital words in movie/shows overview in our dataset

# %%
from wordcloud import WordCloud
plt.figure(figsize=(12, 10))
plt.title('The Most Common Word in Movie Overviews\n', fontsize=10, weight=600, color='#333d29')
wc = WordCloud(max_words=1000, min_font_size=10,
                height=800,width=1600,background_color="black", colormap='plasma').generate(' '.join(df['overview']))

plt.imshow(wc)

# %% [markdown]
# Find, Family, Life, Man, Discover etc are the most conspicous words in our text.

# %%
df.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# ...

# %%
# reating a copy of our dataframe
df3 =df.copy()

# %%
df3['overview'] = df3['overview'].apply(lambda x : x if isinstance(x, list) else [x])

# %%
# combining genres,overview,keywords, cast into one column; tags
df3['tags'] = df3['genres'] + df3['overview'] + df3['keywords'] + df3['cast']
# a new dataframe made up of 3 columns
new_df = df3[['movie_id', 'title', 'tags']]
new_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  [Action, Adventure, Fantasy, Science Fiction, ...
# 1  [Adventure, Fantasy, Action, Captain Barbossa,...
# 2  [Action, Adventure, Crime, A cryptic message f...
# 3  [Action, Crime, Drama, Thriller, Following the...
# 4  [Action, Adventure, Science Fiction, John Cart...

# %%
# converting the datatype of tags into strings
new_df['tags'] = new_df['tags'].astype(str)
# Out:
# C:\Users\test\AppData\Local\Temp\ipykernel_5908\3365301815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].astype(str)

# %%
# changing tags from proper case to lower case
new_df['tags'] = new_df['tags'].apply(lambda x : x.lower())
# Out:
# C:\Users\test\AppData\Local\Temp\ipykernel_5908\3679624391.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x : x.lower())

# %% [markdown]
# Bagging of words

# %% [markdown]
# Countvectorizer will convert text to a sparse matrix of numrical data. stop_words will remove words that don't add meaning to our text like articles,prepositions and interjections from our text.

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 5000, stop_words = 'english')

# %%
# applying count vectorizer to our text
count_vectors = cv.fit_transform(new_df['tags']).toarray()

# %% [markdown]
# we will modify words to their basic format example walking => walk, eaten => eat using WordNetLemmatizer

# %%
from nltk.stem.wordnet import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
# a function modify words
def lemmatizing(text):
    sentence = []
    for i in text.split():
        sentence.append(lemmatizer.lemmatize(i))
    return " ".join(sentence)

# %%
# applying our function to tags column
new_df['tags'].apply(lemmatizing)
# Out:
# 0       ['action', 'adventure', 'fantasy', 'science fi...
# 1       ['adventure', 'fantasy', 'action', 'captain ba...
# 2       ['action', 'adventure', 'crime', 'a cryptic me...
# 3       ['action', 'crime', 'drama', 'thriller', "foll...
# 4       ['action', 'adventure', 'science fiction', "jo...
#                               ...
# 4804    ['action', 'crime', 'thriller', 'el mariachi j...
# 4805    ['comedy', 'romance', "a newlywed couple's hon...
# 4806    ['comedy', 'drama', 'romance', 'tv movie', '"s...
# 4807    ['when ambitious new york attorney sam is sent...
# 4808    ['documentary', "ever since the second grade w...
# Name: tags, Length: 4809, dtype: object

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(count_vectors)

# %%
similarity
# Out:
# array([[1.        , 0.10250915, 0.06518844, ..., 0.01982629, 0.03434014,
#         0.01703748],
#        [0.10250915, 1.        , 0.04722238, ..., 0.02872425, 0.01658395,
#         0.01234192],
#        [0.06518844, 0.04722238, 1.        , ..., 0.01369992, 0.0158193 ,
#         0.        ],
#        ...,
#        [0.01982629, 0.02872425, 0.01369992, ..., 1.        , 0.07216878,
#         0.05370862],
#        [0.03434014, 0.01658395, 0.0158193 , ..., 0.07216878, 1.        ,
#         0.04134491],
#        [0.01703748, 0.01234192, 0.        , ..., 0.05370862, 0.04134491,
#         1.        ]])

# %%
# creating indices of  movies and shows
indices = pd.Series(new_df.index, index=new_df['title'])
indices
# Out:
# title
# Avatar                                         0
# Pirates of the Caribbean: At World's End       1
# Spectre                                        2
# The Dark Knight Rises                          3
# John Carter                                    4
#                                             ...
# El Mariachi                                 4804
# Newlyweds                                   4805
# Signed, Sealed, Delivered                   4806
# Shanghai Calling                            4807
# My Date with Drew                           4808
# Length: 4809, dtype: int64

# %% [markdown]
# Movie Recommendations

# %% [markdown]
# below is a function that we will use to make recommendations on a movie or show that a user prefers based on the content that is in the movie.this will depend on tags column.

# %%
# a function that takes in movie title as inputs and simillar movies as output
def get_recommedations(title):
    idx = indices[title]
    sim_scores_desc = list(enumerate(similarity[idx]))
    sim_scores_desc = sorted(sim_scores_desc, key=lambda x : x[1], reverse=True)
    sim_scores_desc = sim_scores_desc[1:11]
    movie_indices = [i[0] for i in sim_scores_desc]
    return new_df[['movie_id', 'title', 'tags']].iloc[movie_indices]

# %%
# movie recommedations similar to spectre
get_recommedations("Spectre")
# Out:
#       movie_id                            title  \
# 29       37724                          Skyfall
# 11       10764                Quantum of Solace
# 147      36669                  Die Another Day
# 4078       657            From Russia with Love
# 4345       646                           Dr. No
# 3148       667              You Only Live Twice
# 1346     36670            Never Say Never Again
# 3167       660                      Thunderball
# 3256       668  On Her Majesty's Secret Service
# 3891       658                       Goldfinger
#
#                                                    tags
# 29    ['action', 'adventure', 'thriller', "when bond...
# 11    ['adventure', 'action', 'thriller', 'crime', '...
# 147   ['adventure', 'action', 'thriller', "bond take...
# 4078  ['action', 'thriller', 'adventure', 'agent 007...
# 4345  ['adventure', 'action', 'thriller', 'in the fi...
# 3148  ['action', 'thriller', 'adventure', 'a mysteri...
# ...

# %% [markdown]
# we can see that all movies recommended are simillar to spectre in relation to genre, cast, overview and keywords
